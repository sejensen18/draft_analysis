# %%
import numpy as np
import pandas as pd
import h2o

data = pd.read_csv('../data/output.csv', header=None, 
                   names = ["Pick", "Team", "Name", "Position", "School", "Year"])

data[["Pick", "Team", "Name", "Position", "School", "Year"]].groupby(["School", "Year"]).agg(['mean', 'count'])
# Out:
#                               Pick
#                               mean  count
# School            Year
# Abilene Christian 1967  248.500000      2
#                   1969  436.000000      1
#                   1970   60.000000      1
#                   1971   44.000000      1
#                   1972  189.000000      1
#                   1973  256.000000      1
#                   1974  103.000000      1
#                   1975  347.000000      1
#                   1976  399.000000      1
#                   1977  167.333333      3
#                   1983  226.500000      2
#                   1985  252.000000      1
#                   2006   42.000000      1
#                   2009  174.500000      2
#                   2011  111.000000      1
#                   2012  252.000000      1
# Adams State       1967  234.000000      2
#                   1968  297.000000      2
#                   1969  396.000000      1
# Air Force         1971  257.000000      1
# ...

# %%
data[["Pick", "Team", "Name", "Position", "School", "Year"]].groupby(["School", "Year"]).agg(['count'])
# Out:
#                          Pick   Team   Name  Position
#                         count  count  count     count
# School            Year
# Abilene Christian 1967      2      2      2         2
#                   1969      1      1      1         1
#                   1970      1      1      1         1
#                   1971      1      1      1         1
#                   1972      1      1      1         1
#                   1973      1      1      1         1
#                   1974      1      1      1         1
#                   1975      1      1      1         1
#                   1976      1      1      1         1
#                   1977      3      3      3         3
#                   1983      2      2      2         2
#                   1985      1      1      1         1
#                   2006      1      1      1         1
#                   2009      2      2      2         2
#                   2011      1      1      1         1
# ...
